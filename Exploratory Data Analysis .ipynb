# %% [markdown]
# <h1 style="color:green;">       Exploratory Data Analysis (EDA)</h1>

# %% [markdown]
# <h4 style="color:blue;"> Providing a dataset from ABC company, it consisting of 458 rows and 9 columns. The company requires a comprehensive report detailing information about their employees across various teams. preprocessing the dataset, analyzing the data, and presenting  findings graphically.
# I will use various methods of exploratory data analysis to examine the characteristics</h4>

# %% [markdown]
# <h4>Import necessary modules</h4>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('myexcel.xlsx')
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %% [markdown]
# creating a data frame and load the excel file to data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# info() function print the summary of data frame

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# describe function used to find statistical summary of numerical and categorical values like count,min,max, mean etc..

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# to view all columns in abc company data set

# %%
df.head(11)
# Out:
#                Name            Team  Number Position  Age  \
# 0     Avery Bradley  Boston Celtics       0       PG   25
# 1       Jae Crowder  Boston Celtics      99       SF   25
# 2      John Holland  Boston Celtics      30       SG   27
# 3       R.J. Hunter  Boston Celtics      28       SG   22
# 4     Jonas Jerebko  Boston Celtics       8       PF   29
# 5      Amir Johnson  Boston Celtics      90       PF   29
# 6     Jordan Mickey  Boston Celtics      55       PF   21
# 7      Kelly Olynyk  Boston Celtics      41        C   25
# 8      Terry Rozier  Boston Celtics      12       PG   22
# 9      Marcus Smart  Boston Celtics      36       PG   22
# 10  Jared Sullinger  Boston Celtics       7        C   24
#
#                  Height  Weight            College      Salary
# 0   2023-02-06 00:00:00     180              Texas   7730337.0
# 1   2023-06-06 00:00:00     235          Marquette   6796117.0
# 2   2023-05-06 00:00:00     205  Boston University         NaN
# ...

# %% [markdown]
# Display the first few rows of the dataset using head or perview of data set

# %%
df.tail(10)
# Out:
#                Name       Team  Number Position  Age               Height  \
# 448  Gordon Hayward  Utah Jazz      20       SF   26  2023-08-06 00:00:00
# 449     Rodney Hood  Utah Jazz       5       SG   23  2023-08-06 00:00:00
# 450      Joe Ingles  Utah Jazz       2       SF   28  2023-08-06 00:00:00
# 451   Chris Johnson  Utah Jazz      23       SF   26  2023-06-06 00:00:00
# 452      Trey Lyles  Utah Jazz      41       PF   20  2023-10-06 00:00:00
# 453    Shelvin Mack  Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454       Raul Neto  Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455    Tibor Pleiss  Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456     Jeff Withey  Utah Jazz      24        C   26                  7-0
# 457        Priyanka  Utah Jazz      34        C   25  2023-03-07 00:00:00
#
#      Weight   College      Salary
# 448     226    Butler  15409570.0
# 449     206      Duke   1348440.0
# 450     226       NaN   2050000.0
# ...

# %% [markdown]
#  Display the last 10 rows of the dataset using tail or perview of data set

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there is no duplicate values in dataset

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
#  check if there are any missing values ,there is 84 null values in college column and 11 null values in column salary

# %%
df.fillna(0,inplace=True)
print(df)
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     179     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     160     235
# 2     John Holland  Boston Celtics      30       SG   27     162     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     163     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     158     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     158     203
# 454      Raul Neto       Utah Jazz      25       PG   24     151     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     180     256
# 456    Jeff Withey       Utah Jazz      24        C   26     155     231
# 457       Priyanka       Utah Jazz      34        C   25     173     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# filling null value columns "0" using fillna()

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %% [markdown]
# recheck any null values in data set now, there is no null value

# %%
print(df['Height'])
# Out:
# 0      2023-02-06 00:00:00
# 1      2023-06-06 00:00:00
# 2      2023-05-06 00:00:00
# 3      2023-05-06 00:00:00
# 4      2023-10-06 00:00:00
#               ...
# 453    2023-03-06 00:00:00
# 454    2023-01-06 00:00:00
# 455    2023-03-07 00:00:00
# 456                    7-0
# 457    2023-03-07 00:00:00
# Name: Height, Length: 458, dtype: object

# %%
height=np.random.randint(150,181,size=len(df))
df["Height"]=height
print(df['Height'])
# Out:
# 0      179
# 1      160
# 2      162
# 3      163
# 4      158
#       ...
# 453    158
# 454    151
# 455    180
# 456    155
# 457    173
# Name: Height, Length: 458, dtype: int32

# %% [markdown]
# Generate random numbers between 150 and 180 for the "Height" column and update that column in dataframe

# %%
print(df['Height'].describe())
# Out:
# count    458.000000
# mean     164.268559
# std        9.098533
# min      150.000000
# 25%      156.000000
# 50%      163.500000
# 75%      172.000000
# max      180.000000
# Name: Height, dtype: float64

# %% [markdown]
# check data consistency and integrity

# %% [markdown]
# <h3 style="color:blue;"> 1. distribution of employees across each team and calculate the percentage split relative to the total number of employees</h3>

# %%
disribution_emp=df["Team"].value_counts()
print("Distribution of Employees Each Team:\n",disribution_emp)
total_emp=len(df)
percentage_split=(disribution_emp/total_emp)*100
print("percentage of ech employee in team:\n",percentage_split)
# Out:
# Distribution of Employees Each Team:
#  Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# ...

# %% [markdown]
# effectively giving you the count of employees in each team.employees in each team relative to the total number of employees. We divide the count of employees in each team by the total number of employees and then multiply by 100 to convert it into a percentage.prints out the percentage split relative to the total number of employees.

# %% [markdown]
# <h4 style="color:blue;">graphical representation of percentage split of employee</h4>

# %%
plt.figure(figsize=(9,8))
plt.pie( percentage_split,labels=percentage_split.index)
plt.title('Percentage Split of Employees Across Teams')
plt.show()

# %% [markdown]
# display the pie chart with labels indicating the percentage split of employees across teams.

# %% [markdown]
# <h3 style="color:blue;"> 2.Segregate employees based on their positions within the company</h3>

# %%
position_count = df['Position'].value_counts()
print("Employees Segregation Based on Positions:")
print(position_count)
# Out:
# Employees Segregation Based on Positions:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
position_groups = df.groupby('Position')
for position, group in position_groups:
    print("Employees in position:",position)
    print(group)
    print()
# Out:
# Employees in position: C
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     151
# 10   Jared Sullinger          Boston Celtics       7        C   24     177
# 14      Tyler Zeller          Boston Celtics      44        C   26     163
# 23       Brook Lopez           Brooklyn Nets      11        C   28     172
# 27        Henry Sims           Brooklyn Nets      14        C   26     151
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     165
# 447      Rudy Gobert               Utah Jazz      27        C   23     161
# 455     Tibor Pleiss               Utah Jazz      21        C   26     180
# 456      Jeff Withey               Utah Jazz      24        C   26     155
# 457         Priyanka               Utah Jazz      34        C   25     173
#
#      Weight         College      Salary
# ...

# %% [markdown]
# count  total count of employee postions ,.groupby function used to group postions , grops based on same criteria and then applying a function to
# each group independently. SG postion  102,
# PF    100,
# PG     92,
# SF     85,
# C      79 respectively and each employee deatils in group base

# %% [markdown]
# <h4 style="color:blue;">graphical representation of employee Segregate </h4>

# %%
plt.bar(position_count.index, position_count.values,color="black")  
plt.title('Distribution of Employees by Position')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# display the bar chart different categories of employee position

# %% [markdown]
# <h3 style="color:blue;"> 3.predominant age group among employees</h3>

# %%
age_group=df['Age'].value_counts()
age_group
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
group=age_group.idxmax()
print("Predominant Age Group Among Employees:",group)
# Out:
# Predominant Age Group Among Employees: 24

# %% [markdown]
# We then count the number of employees in each age group using value_counts().
# Finally, we determine the predominant age group by finding the index (label) with the maximum count using idxmax().24 is the predominant age group

# %% [markdown]
# <h4 style="color:blue;">graphical representation Predominant Age Group Among Employees </h4>

# %%
plt.bar(age_group.index, age_group.values,color="brown")  
plt.title('Predominant Age Group Among Employees')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# Each point represents an age group, with the x-coordinate representing the age group and the y-coordinate representing the count of
# employees in that age group.

# %% [markdown]
# <h3 style="color:blue;">4.Discover which team and position have the highest salary expenditure</h3>

# %%
s=df["Salary"].value_counts()
print(s)
l=s.idxmax()
l
# Out:
# Salary
# 947276.0     32
# 845059.0     18
# 525093.0     13
# 0.0          11
# 981348.0      6
#              ..
# 2100000.0     1
# 1252440.0     1
# 2891760.0     1
# 3272091.0     1
# 900000.0      1
# Name: count, Length: 310, dtype: int64
# 947276.0

# %% [markdown]
# in this code we find how many employee can get same salary ,947276 is salary 32 employee gets

# %%
salary= df.groupby(['Team', 'Position'])['Salary'].sum()
highest=salary.idxmax()
print("Team and Position with the Highest Salary Expenditure:")
print("Team:", highest[0])
print("Position:", highest[1])
# Out:
# Team and Position with the Highest Salary Expenditure:
# Team: Los Angeles Lakers
# Position: SF

# %% [markdown]
# Group the data by team and position, then calculate total salary expenditure for each group, Find the team and position with the highest
# salary, function returns the index (which is a tuple containing the team and position) where the maximum value occurs in the salary.
# finding the index of the maximum salary expenditure, we directly access the elements of the resulting tuple to retrieve the team and position
# with the highest salary.highest[0] retrieves the team name, and highest[1] retrieves the position name from the tuple.
# team  'LOS ANGELES LAKERS 'get highest salary expenditure and  postion 'SF' get highest salary expenditure

# %% [markdown]
# <h4 style="color:blue;">graphical representation highest salary expenditure. </h4>

# %%
team = highest[0]
position = highest[1]
expenditure = salary[highest]
plt.figure(figsize=(8, 4))
plt.barh(team, expenditure, color='lightblue')
plt.title('Highest Salary by Team')
plt.xlabel('Salary')
plt.ylabel('Team')
plt.show()

# position 
plt.figure(figsize=(8, 4))
plt.barh(position, expenditure, color='lightgreen')
plt.title('Highest Salary by Position')
plt.xlabel('Salary')
plt.ylabel('Position')
plt.show()

# %% [markdown]
# Assuming highest is a tuple containing the team and position with the highest salary expenditure
# Assuming salary is a DataFrame or Series containing the highest salary expenditure by team and position, Plotting the horizontal bar chart for team
# and postion

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['Team'], df['Salary'], color='green')
plt.title('Salary by Team')
plt.xlabel('Team')
plt.ylabel('Salary')
plt.xticks(rotation=45)  
plt.show()

# bar chart for position
plt.figure(figsize=(12, 6))
plt.bar(df['Position'], df['Salary'], color='lightgreen')
plt.title('Salary by Position')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# to visualize the salary expenditure for all teams and all positions separately. In that case, you can create two separate bar charts, one
# for each category team and position.This approach provides separate visualizations for the salary expenditure across all teams and all positions,
# allowing you to analyze the data for each category independently.

# %% [markdown]
# <h3 style="color:blue;"> 5.Investigate if there's any correlation between age and salary</h3>

# %%
correlation = df['Age'].corr(df['Salary'])
print("Correlation between Age and Salary:", correlation)
# Out:
# Correlation between Age and Salary: 0.20500960284809364

# %% [markdown]
# calculate the correlation coefficient between these two variables. The correlation coefficient quantifies the strength and direction of
# the linear relationship between two variables. Here's how you can do it using Python with the corr() method.A correlation coefficient close to
# 1 indicates a strong positive correlation (i.e., as one variable increases, the other variable tends to increase).
# A correlation coefficient close to -1 indicates a strong negative correlation (i.e., as one variable increases, the other variable tends to decrease).
# A correlation coefficient close to 0 indicates little to no linear relationship between the variables.
#
# A value of 0.205 suggests a positive correlation between age and salary, meaning that as age increases, salary tends to increase, and vice versa.
# However, the correlation is weak, indicating that the relationship between age and salary is not very strong.

# %% [markdown]
# <h4 style="color:blue;">Graphical Representation</h4>

# %%
plt.scatter(df["Age"],df["Salary"],color="b")
plt.title('Correlation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# We use plt.scatter() to create a scatter plot.
# The x-axis represents the age of employees Age column, and the y-axis represents their salary Salary column.
# scatter plot allows you to visually assess the correlation between age and salary. If there's a significant correlation,
# observe the pattern,higher salaries tend to certain age ranges 30 to 32 .

# %%
age = df.groupby(df['Age'])['Salary'].mean()
age_group = age.idxmax()
print("Age group with the maximum average salary:",age_group)
# Out:
# Age group with the maximum average salary: 37

# %% [markdown]
# age groups and calculate average salary for each group,and get the maximum amount salary get age group 37

# %%
sns.pairplot(df)

# %% [markdown]
# graphical representation that allows you to visualize pairwise relationships between different variables in a dataset. It's particularly
# useful for exploring the correlations between multiple variables simultaneously.
# The main diagonal would display histograms or kernel density estimation plots for each numerical variable such as 'Age', 'Height', 'Weight', and
# 'Salary'. These plots show the distribution of each variable.The off-diagonal elements would display scatterplots for each pair of
# numerical variables. scatterplots between 'Age' and 'Salary', 'Height' and 'Weight', 'Age' and 'Height',.
# These scatterplots help visualize the relationship between different pairs of variables and identify any potential correlations
# Pair plots facilitate exploratory data analysis, allowing you to gain insights into the relationships and patterns present in the data. For instance,
# you can identify trends such as the relationship between age and salary or the distribution of height and weight across different age groups.
# Overall, a pair plot would provide a comprehensive visual overview of the relationships between different variables in the employee dataset,
# helping in data exploration and analysis
